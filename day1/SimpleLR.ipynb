# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("Package(in LPA)")
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]
print(X.head())
print (Y.head())
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=2)

# %%
X_train.head()
# Out:
#      cgpa
# 28   5.94
# 133  6.05
# 94   5.83
# 42   5.95
# 169  9.31

# %%
y_train.head()
# Out:
# 28     2.24
# 133    2.58
# 94     2.42
# 42     2.54
# 169    4.37
# Name: package, dtype: float64

# %%
X_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
from sklearn.linear_model import  LinearRegression
lr=LinearRegression()
lr.fit(X_test.values,y_test.values)
# Out:
# LinearRegression()

# %%
lr.predict((X_test.iloc[0]).values.reshape(1,1)) 
#error of around 0.18
# Out:
# array([3.928031])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("Package(in LPA)")
plt.plot(X_test,lr.predict(X_test),color="red")
# Out:
# /home/neervana/Downloads/ml/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2684: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
print("slope(m)="+str(lr.coef_))
print("Intercept(b)="+str(lr.intercept_))
print("y=mx+b(predicted data): ",end="")
print((lr.coef_ * X_test.iloc[0].values) + lr.intercept_)
print("Actual data: "+str(y_test.iloc[0]))
# Out:
# slope(m)=[0.60136008]
# Intercept(b)=-1.2316385068202473
# y=mx+b(predicted data): [3.928031]
# Actual data: 4.1
